# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinMamaril/VDA-CpE-031-CpE21S4/blob/main/Exercise7Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Dataset/mamaril.csv"
df = pd.read_csv(path)
df.head(5)
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin            NaN   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter            NaN  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter            NaN  EXP Lane  2646       7.8   453
#
# ...

# %%
print(df.head(5))  # print the first few rows of the dataframe
print(df.shape)  # print the shape of the dataframe (number of rows, columns)
# Out:
#      Name            Title                                         Voice_Line  \
# 0   Aamon   Duke of Shards  It is better to be feared than loved, if you c...
# 1    Akai    Panda Warrior                         Now Akai enters the scene!
# 2  Aldous  Soul Contractor                                       Primary Role
# 3   Alice   Queen of Blood                                   Watch your back!
# 4   Alpha  Blade of Enmity                             Test! Alpha is online.
#
#   Release_Date Primary_Role Secondary_Role      Lane    Hp  Hp_Regen  Mana  \
# 0   2021-10-25     Assassin            NaN   Jungler  2614       8.0   455
# 1         2016         Tank        Support    Roamer  2769       8.4   422
# 2         2018      Fighter            NaN  EXP Lane  2718       9.8   405
# 3         2016         Mage           Tank  EXP Lane  2573       7.2   493
# 4         2017      Fighter            NaN  EXP Lane  2646       7.8   453
#
# ...

# %%
data = {
    'Name': ['Aamon', 'Akai', 'Aldog', 'Alice', 'Alpha'],
    'Title': ['Duke of Shards', 'Panda Warrior', 'Soul Contractor', 'Queen of Blood', 'Blade of enmity'],
    'Release Date': [2021, 2016, 2017, 2016, 2017]
}

df = pd.DataFrame(data)
print(df)
df
# Out:
#     Name            Title  Release Date
# 0  Aamon   Duke of Shards          2021
# 1   Akai    Panda Warrior          2016
# 2  Aldog  Soul Contractor          2017
# 3  Alice   Queen of Blood          2016
# 4  Alpha  Blade of enmity          2017
#     Name            Title  Release Date
# 0  Aamon   Duke of Shards          2021
# 1   Akai    Panda Warrior          2016
# 2  Aldog  Soul Contractor          2017
# 3  Alice   Queen of Blood          2016
# 4  Alpha  Blade of enmity          2017

# %%
data = {
    'Name': ['Aamon', 'Akai', 'Aldog', 'Alice', 'Alpha'],
    'Title': ['Duke of Shards', 'Panda Warrior', 'Soul Contractor', 'Queen of Blood', 'Blade of enmity'],
    'Release Date': ['2021', '2016', '2018', '2016', '2017']
}

df = pd.DataFrame.from_records(data)
print(df)
df
# Out:
#     Name Release Date            Title
# 0  Aamon         2021   Duke of Shards
# 1   Akai         2016    Panda Warrior
# 2  Aldog         2018  Soul Contractor
# 3  Alice         2016   Queen of Blood
# 4  Alpha         2017  Blade of enmity
#     Name Release Date            Title
# 0  Aamon         2021   Duke of Shards
# 1   Akai         2016    Panda Warrior
# 2  Aldog         2018  Soul Contractor
# 3  Alice         2016   Queen of Blood
# 4  Alpha         2017  Blade of enmity

# %%
name_column = df.loc[:, 'Title']
print(name_column)
# Out:
# 0     Duke of Shards
# 1      Panda Warrior
# 2    Soul Contractor
# 3     Queen of Blood
# 4    Blade of enmity
# Name: Title, dtype: object

# %%
rows = df.iloc[[0, 2]]
print(rows)
# Out:
#     Name Release Date            Title
# 0  Aamon         2021   Duke of Shards
# 2  Aldog         2018  Soul Contractor
